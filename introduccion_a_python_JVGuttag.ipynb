# %% [markdown]
# <a href="https://colab.research.google.com/github/mariluvarela/PHYTON/blob/main/introduccion_a_python_JVGuttag.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# INTRODUCCIÓN A PYTHON: Libro de Jhon V. Guttag, segunda edición.

# %%
print('Yankees rules!')
print('But not in Boston!')
print('Yankees rules, but noy in Boston!')
# Out:
# Yankees rules!
# But not in Boston!
# Yankees rules, but noy in Boston!

# %% [markdown]
# Objetos, Expresiones y Tipos numéricos.

# %%
>>> 3+2
>>> 3.0+2.0
>>> 3 !=2
>>> type(3)
>>> type (3.0)
6%4
# Out:
# 2
